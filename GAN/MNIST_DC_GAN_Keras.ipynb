# %%
# https://keras.io/
# !pip install -q keras
import keras

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD
from keras.datasets import mnist
import numpy as np
from PIL import Image
import argparse
import math


def generator_model():
    model = Sequential()
    model.add(Dense(input_dim=100, output_dim=1024))
    model.add(Activation('tanh'))
    model.add(Dense(128*7*7))
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    model.add(Reshape((7, 7, 128), input_shape=(128*7*7,)))
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(64, (5, 5), padding='same'))
    model.add(Activation('tanh'))
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(1, (5, 5), padding='same'))
    model.add(Activation('tanh'))
    return model


def discriminator_model():
    model = Sequential()
    model.add(
            Conv2D(64, (5, 5),
            padding='same',
            input_shape=(28, 28, 1))
            )
    model.add(Activation('tanh'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (5, 5)))
    model.add(Activation('tanh'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation('tanh'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model


def generator_containing_discriminator(g, d):
    model = Sequential()
    model.add(g)
    d.trainable = False
    model.add(d)
    return model


def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[1:3]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[:, :, 0]
    return image


def train(BATCH_SIZE):
    (X_train, y_train), (X_test, y_test) = mnist.load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train[:, :, :, None]
    X_test = X_test[:, :, :, None]
    # X_train = X_train.reshape((X_train.shape, 1) + X_train.shape[1:])
    d = discriminator_model()
    g = generator_model()
    d_on_g = generator_containing_discriminator(g, d)
    d_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g.compile(loss='binary_crossentropy', optimizer="SGD")
    d_on_g.compile(loss='binary_crossentropy', optimizer=g_optim)
    d.trainable = True
    d.compile(loss='binary_crossentropy', optimizer=d_optim)
    for epoch in range(100):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            noise = np.random.uniform(-1, 1, size=(BATCH_SIZE, 100))
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            generated_images = g.predict(noise, verbose=0)
            if index % 20 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                Image.fromarray(image.astype(np.uint8)).save(
                    str(epoch)+"_"+str(index)+".png")
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = d.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            noise = np.random.uniform(-1, 1, (BATCH_SIZE, 100))
            d.trainable = False
            g_loss = d_on_g.train_on_batch(noise, [1] * BATCH_SIZE)
            d.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if index % 10 == 9:
                g.save_weights('generator', True)
                d.save_weights('discriminator', True)


def generate(BATCH_SIZE, nice=False):
    g = generator_model()
    g.compile(loss='binary_crossentropy', optimizer="SGD")
    g.load_weights('generator')
    if nice:
        d = discriminator_model()
        d.compile(loss='binary_crossentropy', optimizer="SGD")
        d.load_weights('discriminator')
        noise = np.random.uniform(-1, 1, (BATCH_SIZE*20, 100))
        generated_images = g.predict(noise, verbose=1)
        d_pret = d.predict(generated_images, verbose=1)
        index = np.arange(0, BATCH_SIZE*20)
        index.resize((BATCH_SIZE*20, 1))
        pre_with_index = list(np.append(d_pret, index, axis=1))
        pre_with_index.sort(key=lambda x: x[0], reverse=True)
        nice_images = np.zeros((BATCH_SIZE,) + generated_images.shape[1:3], dtype=np.float32)
        nice_images = nice_images[:, :, :, None]
        for i in range(BATCH_SIZE):
            idx = int(pre_with_index[i][1])
            nice_images[i, :, :, 0] = generated_images[idx, :, :, 0]
        image = combine_images(nice_images)
    else:
        noise = np.random.uniform(-1, 1, (BATCH_SIZE, 100))
        generated_images = g.predict(noise, verbose=1)
        image = combine_images(generated_images)
    image = image*127.5+127.5
    Image.fromarray(image.astype(np.uint8)).save(
        "generated_image.png")
# Out:
# Using TensorFlow backend.

# %%
train(BATCH_SIZE=32)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=100, units=1024)`
# Epoch is 0
# Number of batches 1875
# batch 0 d_loss : 0.717485
# batch 0 g_loss : 0.719484
# batch 1 d_loss : 0.698724
# batch 1 g_loss : 0.702067
# batch 2 d_loss : 0.693461
# batch 2 g_loss : 0.684042
# batch 3 d_loss : 0.678437
# batch 3 g_loss : 0.677454
# batch 4 d_loss : 0.653074
# batch 4 g_loss : 0.667103
# batch 5 d_loss : 0.636978
# batch 5 g_loss : 0.663174
# batch 6 d_loss : 0.616316
# batch 6 g_loss : 0.646046
# batch 7 d_loss : 0.601052
# batch 7 g_loss : 0.627764
# batch 8 d_loss : 0.567922
# batch 8 g_loss : 0.625304
# batch 9 d_loss : 0.556588
# batch 9 g_loss : 0.603251
# batch 10 d_loss : 0.537633
# batch 10 g_loss : 0.586539
# batch 11 d_loss : 0.525940
# batch 11 g_loss : 0.572845
# batch 12 d_loss : 0.505949
# batch 12 g_loss : 0.564898
# batch 13 d_loss : 0.499069
# batch 13 g_loss : 0.565922
# batch 14 d_loss : 0.494954
# batch 14 g_loss : 0.553155
# batch 15 d_loss : 0.480873
# batch 15 g_loss : 0.547601
# batch 16 d_loss : 0.480038
# batch 16 g_loss : 0.531615
# batch 17 d_loss : 0.466359
# batch 17 g_loss : 0.534420
# batch 18 d_loss : 0.468080
# batch 18 g_loss : 0.518166
# batch 19 d_loss : 0.459180
# batch 19 g_loss : 0.514113
# batch 20 d_loss : 0.462009
# batch 20 g_loss : 0.520266
# batch 21 d_loss : 0.467847
# batch 21 g_loss : 0.504512
# batch 22 d_loss : 0.458845
# batch 22 g_loss : 0.514581
# batch 23 d_loss : 0.460418
# batch 23 g_loss : 0.504964
# batch 24 d_loss : 0.455137
# batch 24 g_loss : 0.497008
# batch 25 d_loss : 0.456493
# batch 25 g_loss : 0.495391
# batch 26 d_loss : 0.458341
# batch 26 g_loss : 0.498955
# batch 27 d_loss : 0.464742
# batch 27 g_loss : 0.498836
# batch 28 d_loss : 0.467009
# batch 28 g_loss : 0.499215
# batch 29 d_loss : 0.459605
# batch 29 g_loss : 0.493289
# batch 30 d_loss : 0.452345
# batch 30 g_loss : 0.506613
# batch 31 d_loss : 0.461068
# batch 31 g_loss : 0.490636
# batch 32 d_loss : 0.466687
# batch 32 g_loss : 0.498613
# batch 33 d_loss : 0.462036
# batch 33 g_loss : 0.511794
# batch 34 d_loss : 0.465041
# batch 34 g_loss : 0.503118
# batch 35 d_loss : 0.459717
# batch 35 g_loss : 0.518890
# batch 36 d_loss : 0.468905
# batch 36 g_loss : 0.507930
# batch 37 d_loss : 0.485624
# batch 37 g_loss : 0.526337
# batch 38 d_loss : 0.479408
# batch 38 g_loss : 0.521243
# batch 39 d_loss : 0.494287
# batch 39 g_loss : 0.531731
# batch 40 d_loss : 0.490192
# batch 40 g_loss : 0.533484
# batch 41 d_loss : 0.469627
# batch 41 g_loss : 0.562088
# batch 42 d_loss : 0.491854
# batch 42 g_loss : 0.546540
# batch 43 d_loss : 0.487662
# batch 43 g_loss : 0.566298
# batch 44 d_loss : 0.483295
# batch 44 g_loss : 0.567284
# batch 45 d_loss : 0.484793
# batch 45 g_loss : 0.587342
# batch 46 d_loss : 0.482037
# batch 46 g_loss : 0.586517
# batch 47 d_loss : 0.484432
# batch 47 g_loss : 0.589921
# batch 48 d_loss : 0.481071
# batch 48 g_loss : 0.606750
# batch 49 d_loss : 0.483135
# batch 49 g_loss : 0.596702
# batch 50 d_loss : 0.488583
# batch 50 g_loss : 0.622376
# batch 51 d_loss : 0.482276
# batch 51 g_loss : 0.635045
# batch 52 d_loss : 0.490236
# batch 52 g_loss : 0.641752
# batch 53 d_loss : 0.486150
# batch 53 g_loss : 0.659799
# batch 54 d_loss : 0.475795
# batch 54 g_loss : 0.653472
# batch 55 d_loss : 0.479797
# batch 55 g_loss : 0.656435
# batch 56 d_loss : 0.477992
# batch 56 g_loss : 0.685406
# batch 57 d_loss : 0.477428
# batch 57 g_loss : 0.692461
# batch 58 d_loss : 0.484848
# batch 58 g_loss : 0.706465
# batch 59 d_loss : 0.472120
# batch 59 g_loss : 0.714599
# batch 60 d_loss : 0.465549
# batch 60 g_loss : 0.726593
# batch 61 d_loss : 0.474384
# batch 61 g_loss : 0.733223
# batch 62 d_loss : 0.473118
# batch 62 g_loss : 0.747102
# batch 63 d_loss : 0.459030
# batch 63 g_loss : 0.755358
# batch 64 d_loss : 0.470459
# batch 64 g_loss : 0.778687
# batch 65 d_loss : 0.457188
# batch 65 g_loss : 0.786526
# batch 66 d_loss : 0.458644
# batch 66 g_loss : 0.791676
# batch 67 d_loss : 0.461949
# batch 67 g_loss : 0.790275
# batch 68 d_loss : 0.449053
# batch 68 g_loss : 0.799368
# batch 69 d_loss : 0.446259
# batch 69 g_loss : 0.827378
# batch 70 d_loss : 0.467443
# batch 70 g_loss : 0.815307
# batch 71 d_loss : 0.442005
# batch 71 g_loss : 0.828026
# batch 72 d_loss : 0.446611
# batch 72 g_loss : 0.819415
# batch 73 d_loss : 0.439120
# batch 73 g_loss : 0.849401
# batch 74 d_loss : 0.427047
# batch 74 g_loss : 0.856220
# batch 75 d_loss : 0.437767
# batch 75 g_loss : 0.861622
# batch 76 d_loss : 0.414335
# batch 76 g_loss : 0.855015
# batch 77 d_loss : 0.417655
# batch 77 g_loss : 0.869901
# batch 78 d_loss : 0.403287
# batch 78 g_loss : 0.896914
# batch 79 d_loss : 0.409903
# batch 79 g_loss : 0.887206
# batch 80 d_loss : 0.389115
# batch 80 g_loss : 0.890865
# batch 81 d_loss : 0.410716
# batch 81 g_loss : 0.893454
# batch 82 d_loss : 0.395275
# batch 82 g_loss : 0.897070
# batch 83 d_loss : 0.376309
# batch 83 g_loss : 0.902941
# batch 84 d_loss : 0.380280
# batch 84 g_loss : 0.914100
# batch 85 d_loss : 0.415978
# batch 85 g_loss : 0.918294
# batch 86 d_loss : 0.386203
# batch 86 g_loss : 0.939365
# batch 87 d_loss : 0.371412
# batch 87 g_loss : 0.923476
# batch 88 d_loss : 0.360340
# batch 88 g_loss : 0.910640
# batch 89 d_loss : 0.353906
# batch 89 g_loss : 0.955543
# batch 90 d_loss : 0.355509
# batch 90 g_loss : 0.939080
# batch 91 d_loss : 0.345863
# batch 91 g_loss : 0.968852
# batch 92 d_loss : 0.340162
# batch 92 g_loss : 0.959435
# batch 93 d_loss : 0.330964
# batch 93 g_loss : 0.937665
# batch 94 d_loss : 0.327395
# batch 94 g_loss : 0.963462
# batch 95 d_loss : 0.323632
# batch 95 g_loss : 0.966087
# batch 96 d_loss : 0.304274
# batch 96 g_loss : 0.958233
# batch 97 d_loss : 0.327758
# batch 97 g_loss : 0.961294
# batch 98 d_loss : 0.296743
# batch 98 g_loss : 0.958605
# batch 99 d_loss : 0.294742
# batch 99 g_loss : 0.972528
# batch 100 d_loss : 0.313257
# batch 100 g_loss : 0.992612
# batch 101 d_loss : 0.271482
# batch 101 g_loss : 0.972833
# batch 102 d_loss : 0.283375
# batch 102 g_loss : 0.986423
# batch 103 d_loss : 0.271402
# batch 103 g_loss : 0.983255
# batch 104 d_loss : 0.265264
# batch 104 g_loss : 0.978721
# batch 105 d_loss : 0.267456
# batch 105 g_loss : 0.938725
# batch 106 d_loss : 0.276980
# batch 106 g_loss : 0.998156
# batch 107 d_loss : 0.294951
# batch 107 g_loss : 0.964847
# batch 108 d_loss : 0.246511
# batch 108 g_loss : 0.968513
# batch 109 d_loss : 0.257531
# batch 109 g_loss : 0.955460
# batch 110 d_loss : 0.260671
# batch 110 g_loss : 0.955396
# batch 111 d_loss : 0.257607
# batch 111 g_loss : 0.996021
# batch 112 d_loss : 0.255818
# batch 112 g_loss : 0.996001
# batch 113 d_loss : 0.252152
# batch 113 g_loss : 0.979208
# batch 114 d_loss : 0.220416
# batch 114 g_loss : 0.971911
# batch 115 d_loss : 0.236215
# batch 115 g_loss : 0.947964
# batch 116 d_loss : 0.257532
# batch 116 g_loss : 0.930438
# batch 117 d_loss : 0.246730
# batch 117 g_loss : 0.920695
# batch 118 d_loss : 0.243036
# batch 118 g_loss : 0.912559
# batch 119 d_loss : 0.228828
# batch 119 g_loss : 0.957521
# batch 120 d_loss : 0.202338
# batch 120 g_loss : 0.890505
# batch 121 d_loss : 0.249666
# batch 121 g_loss : 0.939287
# batch 122 d_loss : 0.217585
# batch 122 g_loss : 0.888365
# batch 123 d_loss : 0.218509
# batch 123 g_loss : 0.935938
# batch 124 d_loss : 0.193129
# batch 124 g_loss : 0.880950
# batch 125 d_loss : 0.234411
# batch 125 g_loss : 0.866072
# batch 126 d_loss : 0.201418
# batch 126 g_loss : 0.835991
# batch 127 d_loss : 0.211366
# batch 127 g_loss : 0.893671
# batch 128 d_loss : 0.213214
# batch 128 g_loss : 0.898228
# batch 129 d_loss : 0.237346
# batch 129 g_loss : 0.874721
# batch 130 d_loss : 0.242065
# batch 130 g_loss : 0.854852
# batch 131 d_loss : 0.222391
# batch 131 g_loss : 0.790030
# batch 132 d_loss : 0.202548
# batch 132 g_loss : 0.826577
# batch 133 d_loss : 0.203107
# batch 133 g_loss : 0.845074
# batch 134 d_loss : 0.217046
# batch 134 g_loss : 0.794136
# batch 135 d_loss : 0.211279
# batch 135 g_loss : 0.795887
# batch 136 d_loss : 0.238505
# batch 136 g_loss : 0.792137
# batch 137 d_loss : 0.254808
# batch 137 g_loss : 0.810821
# batch 138 d_loss : 0.253503
# batch 138 g_loss : 0.848148
# batch 139 d_loss : 0.216798
# batch 139 g_loss : 0.826780
# batch 140 d_loss : 0.230340
# batch 140 g_loss : 0.784340
# batch 141 d_loss : 0.224372
# batch 141 g_loss : 0.823959
# batch 142 d_loss : 0.244691
# batch 142 g_loss : 0.746774
# batch 143 d_loss : 0.241354
# batch 143 g_loss : 0.743425
# batch 144 d_loss : 0.229420
# batch 144 g_loss : 0.748061
# batch 145 d_loss : 0.241381
# batch 145 g_loss : 0.807617
# batch 146 d_loss : 0.253590
# batch 146 g_loss : 0.715998
# batch 147 d_loss : 0.243987
# batch 147 g_loss : 0.804791
# batch 148 d_loss : 0.304952
# batch 148 g_loss : 0.824941
# batch 149 d_loss : 0.307045
# batch 149 g_loss : 0.764932
# batch 150 d_loss : 0.249928
# batch 150 g_loss : 0.721685
# batch 151 d_loss : 0.288292
# batch 151 g_loss : 0.760774
# batch 152 d_loss : 0.257234
# batch 152 g_loss : 0.753213
# batch 153 d_loss : 0.302573
# batch 153 g_loss : 0.771107
# batch 154 d_loss : 0.284078
# batch 154 g_loss : 0.768545
# batch 155 d_loss : 0.291911
# batch 155 g_loss : 0.779413
# batch 156 d_loss : 0.292563
# batch 156 g_loss : 0.805956
# batch 157 d_loss : 0.245907
# batch 157 g_loss : 0.760745
# batch 158 d_loss : 0.290417
# batch 158 g_loss : 0.755286
# batch 159 d_loss : 0.255706
# batch 159 g_loss : 0.833674
# batch 160 d_loss : 0.268355
# batch 160 g_loss : 0.815905
# batch 161 d_loss : 0.256403
# batch 161 g_loss : 0.839925
# batch 162 d_loss : 0.286654
# batch 162 g_loss : 0.882778
# batch 163 d_loss : 0.258892
# batch 163 g_loss : 0.895843
# batch 164 d_loss : 0.238373
# batch 164 g_loss : 0.914268
# batch 165 d_loss : 0.286694
# batch 165 g_loss : 0.907095
# batch 166 d_loss : 0.243652
# batch 166 g_loss : 0.995873
# batch 167 d_loss : 0.248906
# batch 167 g_loss : 0.976548
# batch 168 d_loss : 0.249957
# batch 168 g_loss : 1.026001
# batch 169 d_loss : 0.243866
# batch 169 g_loss : 1.047880
# batch 170 d_loss : 0.220836
# batch 170 g_loss : 1.069216
# batch 171 d_loss : 0.240525
# batch 171 g_loss : 1.093905
# batch 172 d_loss : 0.212935
# batch 172 g_loss : 1.158304
# batch 173 d_loss : 0.204596
# batch 173 g_loss : 1.144234
# batch 174 d_loss : 0.190524
# batch 174 g_loss : 1.223470
# batch 175 d_loss : 0.211828
# batch 175 g_loss : 1.272515
# batch 176 d_loss : 0.213920
# batch 176 g_loss : 1.344958
# batch 177 d_loss : 0.207336
# batch 177 g_loss : 1.309148
# batch 178 d_loss : 0.196371
# batch 178 g_loss : 1.470829
# batch 179 d_loss : 0.169570
# batch 179 g_loss : 1.363021
# batch 180 d_loss : 0.188669
# batch 180 g_loss : 1.416994
# batch 181 d_loss : 0.185195
# batch 181 g_loss : 1.534413
# batch 182 d_loss : 0.187654
# batch 182 g_loss : 1.499311
# batch 183 d_loss : 0.179156
# batch 183 g_loss : 1.561709
# batch 184 d_loss : 0.154196
# batch 184 g_loss : 1.596818
# batch 185 d_loss : 0.152632
# batch 185 g_loss : 1.666480
# batch 186 d_loss : 0.151507
# batch 186 g_loss : 1.740668
# batch 187 d_loss : 0.139081
# batch 187 g_loss : 1.725403
# batch 188 d_loss : 0.147928
# batch 188 g_loss : 1.786164
# batch 189 d_loss : 0.149330
# batch 189 g_loss : 1.726854
# batch 190 d_loss : 0.146678
# batch 190 g_loss : 1.908745
# batch 191 d_loss : 0.146786
# batch 191 g_loss : 1.828487
# batch 192 d_loss : 0.146801
# batch 192 g_loss : 1.848895
# batch 193 d_loss : 0.138801
# batch 193 g_loss : 1.861458
# batch 194 d_loss : 0.139676
# batch 194 g_loss : 1.988830
# batch 195 d_loss : 0.144317
# batch 195 g_loss : 1.925780
# batch 196 d_loss : 0.150214
# batch 196 g_loss : 1.904647
# batch 197 d_loss : 0.153408
# batch 197 g_loss : 2.036399
# batch 198 d_loss : 0.138014
# batch 198 g_loss : 2.027717
# batch 199 d_loss : 0.153001
# batch 199 g_loss : 2.102165
# batch 200 d_loss : 0.182865
# batch 200 g_loss : 2.075833
# batch 201 d_loss : 0.170136
# batch 201 g_loss : 1.973064
# batch 202 d_loss : 0.187219
# batch 202 g_loss : 2.018496
# batch 203 d_loss : 0.186363
# batch 203 g_loss : 1.982058
# batch 204 d_loss : 0.176826
# batch 204 g_loss : 2.042119
# batch 205 d_loss : 0.194040
# batch 205 g_loss : 2.065595
# batch 206 d_loss : 0.209134
# batch 206 g_loss : 2.103377
# batch 207 d_loss : 0.199347
# batch 207 g_loss : 2.138660
# batch 208 d_loss : 0.212387
# batch 208 g_loss : 2.084332
# batch 209 d_loss : 0.246448
# batch 209 g_loss : 1.988758
# batch 210 d_loss : 0.287121
# batch 210 g_loss : 2.048071
# batch 211 d_loss : 0.251909
# batch 211 g_loss : 2.009274
# batch 212 d_loss : 0.238052
# batch 212 g_loss : 1.925360
# batch 213 d_loss : 0.260924
# batch 213 g_loss : 1.922014
# batch 214 d_loss : 0.262542
# batch 214 g_loss : 1.969346
# batch 215 d_loss : 0.247410
# batch 215 g_loss : 2.009723
# batch 216 d_loss : 0.269353
# batch 216 g_loss : 2.029896
# batch 217 d_loss : 0.216825
# batch 217 g_loss : 1.961830
# batch 218 d_loss : 0.270179
# batch 218 g_loss : 1.894017
# batch 219 d_loss : 0.292286
# batch 219 g_loss : 1.900956
# batch 220 d_loss : 0.337569
# batch 220 g_loss : 1.864774
# batch 221 d_loss : 0.312495
# batch 221 g_loss : 1.971685
# batch 222 d_loss : 0.325151
# batch 222 g_loss : 1.783188
# batch 223 d_loss : 0.304990
# batch 223 g_loss : 1.829168
# batch 224 d_loss : 0.286815
# batch 224 g_loss : 1.743191
# batch 225 d_loss : 0.322598
# batch 225 g_loss : 1.593516
# batch 226 d_loss : 0.343463
# batch 226 g_loss : 1.576733
# batch 227 d_loss : 0.312693
# batch 227 g_loss : 1.493155
# batch 228 d_loss : 0.338622
# batch 228 g_loss : 1.365752
# batch 229 d_loss : 0.386430
# batch 229 g_loss : 1.301359
# batch 230 d_loss : 0.346199
# batch 230 g_loss : 1.316234
# batch 231 d_loss : 0.356005
# batch 231 g_loss : 1.077727
# batch 232 d_loss : 0.322844
# batch 232 g_loss : 1.123958
# batch 233 d_loss : 0.322148
# batch 233 g_loss : 1.245688
# batch 234 d_loss : 0.273867
# batch 234 g_loss : 1.167214
# batch 235 d_loss : 0.257886
# batch 235 g_loss : 1.293571
# batch 236 d_loss : 0.324961
# batch 236 g_loss : 1.411381
# batch 237 d_loss : 0.358896
# batch 237 g_loss : 1.329022
# batch 238 d_loss : 0.253856
# batch 238 g_loss : 1.302292
# batch 239 d_loss : 0.294918
# batch 239 g_loss : 1.314123
# batch 240 d_loss : 0.253588
# batch 240 g_loss : 1.350286
# batch 241 d_loss : 0.271104
# batch 241 g_loss : 1.344439
# batch 242 d_loss : 0.328502
# batch 242 g_loss : 1.288320
# batch 243 d_loss : 0.270369
# batch 243 g_loss : 1.229274
# batch 244 d_loss : 0.227734
# batch 244 g_loss : 1.259859
# batch 245 d_loss : 0.273715
# batch 245 g_loss : 1.149828
# batch 246 d_loss : 0.267548
# batch 246 g_loss : 1.236867
# batch 247 d_loss : 0.277710
# batch 247 g_loss : 1.307840
# batch 248 d_loss : 0.229468
# batch 248 g_loss : 1.338867
# batch 249 d_loss : 0.239310
# batch 249 g_loss : 1.384902
# batch 250 d_loss : 0.264271
# batch 250 g_loss : 1.153785
# batch 251 d_loss : 0.291228
# batch 251 g_loss : 1.137458
# batch 252 d_loss : 0.292275
# batch 252 g_loss : 1.200788
# batch 253 d_loss : 0.246713
# batch 253 g_loss : 1.188179
# batch 254 d_loss : 0.241542
# batch 254 g_loss : 1.256591
# batch 255 d_loss : 0.428241
# batch 255 g_loss : 1.084184
# batch 256 d_loss : 0.389458
# batch 256 g_loss : 0.854539
# batch 257 d_loss : 0.359206
# batch 257 g_loss : 0.933690
# batch 258 d_loss : 0.248440
# batch 258 g_loss : 0.906553
# batch 259 d_loss : 0.296469
# batch 259 g_loss : 1.020294
# batch 260 d_loss : 0.396627
# batch 260 g_loss : 1.050545
# batch 261 d_loss : 0.295068
# batch 261 g_loss : 0.957133
# batch 262 d_loss : 0.349284
# batch 262 g_loss : 1.006088
# batch 263 d_loss : 0.416275
# batch 263 g_loss : 1.009579
# batch 264 d_loss : 0.268453
# batch 264 g_loss : 0.878023
# batch 265 d_loss : 0.282336
# batch 265 g_loss : 0.987518
# batch 266 d_loss : 0.399290
# batch 266 g_loss : 1.106277
# batch 267 d_loss : 0.321137
# batch 267 g_loss : 1.258592
# batch 268 d_loss : 0.431774
# batch 268 g_loss : 1.407928
# batch 269 d_loss : 0.397836
# batch 269 g_loss : 1.286252
# batch 270 d_loss : 0.410057
# batch 270 g_loss : 1.201180
# batch 271 d_loss : 0.369610
# batch 271 g_loss : 1.273828
# batch 272 d_loss : 0.316697
# batch 272 g_loss : 1.053680
# batch 273 d_loss : 0.545588
# batch 273 g_loss : 1.008964
# batch 274 d_loss : 0.401346
# batch 274 g_loss : 1.054333
# batch 275 d_loss : 0.483971
# batch 275 g_loss : 1.024089
# batch 276 d_loss : 0.506969
# batch 276 g_loss : 0.779496
# batch 277 d_loss : 0.592206
# batch 277 g_loss : 0.944227
# batch 278 d_loss : 0.488032
# batch 278 g_loss : 0.854602
# batch 279 d_loss : 0.557089
# batch 279 g_loss : 0.917610
# batch 280 d_loss : 0.637383
# batch 280 g_loss : 0.862652
# batch 281 d_loss : 0.555193
# batch 281 g_loss : 0.970925
# batch 282 d_loss : 0.511860
# batch 282 g_loss : 0.901152
# batch 283 d_loss : 0.658160
# batch 283 g_loss : 0.968713
# batch 284 d_loss : 0.574234
# batch 284 g_loss : 0.688803
# batch 285 d_loss : 0.686150
# batch 285 g_loss : 0.899923
# batch 286 d_loss : 0.726060
# batch 286 g_loss : 0.645771
# batch 287 d_loss : 0.657618
# batch 287 g_loss : 0.905779
# batch 288 d_loss : 0.703164
# batch 288 g_loss : 0.895882
# batch 289 d_loss : 0.683595
# batch 289 g_loss : 0.735901
# batch 290 d_loss : 0.712537
# batch 290 g_loss : 0.947737
# batch 291 d_loss : 0.623832
# batch 291 g_loss : 0.858502
# batch 292 d_loss : 0.666619
# batch 292 g_loss : 0.894018
# batch 293 d_loss : 0.675177
# batch 293 g_loss : 1.008875
# batch 294 d_loss : 0.673594
# batch 294 g_loss : 0.982181
# batch 295 d_loss : 0.592068
# batch 295 g_loss : 1.168377
# batch 296 d_loss : 0.655436
# batch 296 g_loss : 1.139459
# batch 297 d_loss : 0.542529
# batch 297 g_loss : 1.181751
# batch 298 d_loss : 0.627051
# batch 298 g_loss : 1.070351
# batch 299 d_loss : 0.548219
# batch 299 g_loss : 1.083404
# batch 300 d_loss : 0.555191
# batch 300 g_loss : 1.088796
# batch 301 d_loss : 0.567398
# batch 301 g_loss : 0.928250
# batch 302 d_loss : 0.545493
# batch 302 g_loss : 1.002749
# batch 303 d_loss : 0.570665
# batch 303 g_loss : 1.087338
# batch 304 d_loss : 0.503118
# batch 304 g_loss : 1.053275
# batch 305 d_loss : 0.516800
# batch 305 g_loss : 1.044044
# batch 306 d_loss : 0.594264
# batch 306 g_loss : 1.063753
# batch 307 d_loss : 0.519214
# batch 307 g_loss : 1.134147
# batch 308 d_loss : 0.530934
# batch 308 g_loss : 1.121230
# batch 309 d_loss : 0.581734
# batch 309 g_loss : 1.097302
# batch 310 d_loss : 0.535517
# batch 310 g_loss : 1.059381
# batch 311 d_loss : 0.567819
# batch 311 g_loss : 0.995289
# batch 312 d_loss : 0.518348
# batch 312 g_loss : 1.003891
# batch 313 d_loss : 0.464727
# batch 313 g_loss : 1.070916
# batch 314 d_loss : 0.545015
# batch 314 g_loss : 1.060147
# batch 315 d_loss : 0.478084
# batch 315 g_loss : 1.168765
# batch 316 d_loss : 0.581226
# batch 316 g_loss : 1.117071
# batch 317 d_loss : 0.578682
# batch 317 g_loss : 1.232405
# batch 318 d_loss : 0.483895
# batch 318 g_loss : 1.074036
# batch 319 d_loss : 0.432535
# batch 319 g_loss : 1.191293
# batch 320 d_loss : 0.449397
# batch 320 g_loss : 1.218771
# batch 321 d_loss : 0.410865
# batch 321 g_loss : 1.270288
# batch 322 d_loss : 0.440934
# batch 322 g_loss : 1.366835
# batch 323 d_loss : 0.591278
# batch 323 g_loss : 1.209366
# batch 324 d_loss : 0.478417
# batch 324 g_loss : 1.208233
# batch 325 d_loss : 0.511578
# batch 325 g_loss : 1.160109
# batch 326 d_loss : 0.461313
# batch 326 g_loss : 1.112550
# batch 327 d_loss : 0.447469
# batch 327 g_loss : 1.090109
# batch 328 d_loss : 0.500459
# batch 328 g_loss : 1.053118
# batch 329 d_loss : 0.478873
# batch 329 g_loss : 1.139866
# batch 330 d_loss : 0.535266
# batch 330 g_loss : 1.056554
# batch 331 d_loss : 0.500296
# batch 331 g_loss : 1.107650
# batch 332 d_loss : 0.556069
# batch 332 g_loss : 1.052992
# batch 333 d_loss : 0.567850
# batch 333 g_loss : 1.031388
# batch 334 d_loss : 0.524631
# batch 334 g_loss : 0.968905
# batch 335 d_loss : 0.497167
# batch 335 g_loss : 0.997608
# batch 336 d_loss : 0.536587
# batch 336 g_loss : 1.005269
# batch 337 d_loss : 0.466342
# batch 337 g_loss : 1.075779
# batch 338 d_loss : 0.442973
# batch 338 g_loss : 1.063259
# batch 339 d_loss : 0.447242
# batch 339 g_loss : 1.239007
# batch 340 d_loss : 0.470848
# batch 340 g_loss : 1.272991
# batch 341 d_loss : 0.501547
# batch 341 g_loss : 1.254667
# batch 342 d_loss : 0.450534
# batch 342 g_loss : 1.184436
# batch 343 d_loss : 0.487411
# batch 343 g_loss : 1.274043
# batch 344 d_loss : 0.527019
# batch 344 g_loss : 1.142279
# batch 345 d_loss : 0.516427
# batch 345 g_loss : 1.071807
# batch 346 d_loss : 0.462891
# batch 346 g_loss : 1.072016
# batch 347 d_loss : 0.517509
# batch 347 g_loss : 1.049471
# batch 348 d_loss : 0.466121
# batch 348 g_loss : 1.049700
# batch 349 d_loss : 0.438942
# batch 349 g_loss : 1.098390
# batch 350 d_loss : 0.479405
# batch 350 g_loss : 1.072609
# batch 351 d_loss : 0.459738
# batch 351 g_loss : 1.126045
# batch 352 d_loss : 0.566759
# batch 352 g_loss : 1.001534
# batch 353 d_loss : 0.476970
# batch 353 g_loss : 1.024679
# batch 354 d_loss : 0.448410
# batch 354 g_loss : 1.012811
# batch 355 d_loss : 0.445039
# batch 355 g_loss : 1.028526
# batch 356 d_loss : 0.506374
# batch 356 g_loss : 1.124238
# batch 357 d_loss : 0.490141
# batch 357 g_loss : 1.158146
# batch 358 d_loss : 0.441101
# batch 358 g_loss : 1.076663
# batch 359 d_loss : 0.528794
# batch 359 g_loss : 0.950903
# batch 360 d_loss : 0.553336
# batch 360 g_loss : 0.966012
# batch 361 d_loss : 0.506482
# batch 361 g_loss : 0.955699
# batch 362 d_loss : 0.540893
# batch 362 g_loss : 0.988625
# batch 363 d_loss : 0.550149
# batch 363 g_loss : 0.979822
# batch 364 d_loss : 0.530677
# batch 364 g_loss : 0.910056
# batch 365 d_loss : 0.472427
# batch 365 g_loss : 0.938065
# batch 366 d_loss : 0.493277
# batch 366 g_loss : 1.105451
# batch 367 d_loss : 0.466388
# batch 367 g_loss : 1.049024
# batch 368 d_loss : 0.440508
# batch 368 g_loss : 1.047308
# batch 369 d_loss : 0.442241
# batch 369 g_loss : 1.016881
# batch 370 d_loss : 0.443744
# batch 370 g_loss : 1.117840
# batch 371 d_loss : 0.443497
# batch 371 g_loss : 1.071037
# batch 372 d_loss : 0.446635
# batch 372 g_loss : 1.126354
# batch 373 d_loss : 0.496747
# batch 373 g_loss : 1.133677
# batch 374 d_loss : 0.462007
# batch 374 g_loss : 1.177933
# batch 375 d_loss : 0.485058
# batch 375 g_loss : 1.166369
# batch 376 d_loss : 0.459951
# batch 376 g_loss : 1.068939
# batch 377 d_loss : 0.504675
# batch 377 g_loss : 1.072213
# batch 378 d_loss : 0.474532
# batch 378 g_loss : 1.067698
# batch 379 d_loss : 0.528425
# batch 379 g_loss : 0.987217
# batch 380 d_loss : 0.492049
# batch 380 g_loss : 1.031184
# batch 381 d_loss : 0.528392
# batch 381 g_loss : 1.078709
# batch 382 d_loss : 0.470727
# batch 382 g_loss : 0.933447
# batch 383 d_loss : 0.465333
# batch 383 g_loss : 1.044527
# batch 384 d_loss : 0.497494
# batch 384 g_loss : 0.985487
# batch 385 d_loss : 0.514644
# batch 385 g_loss : 0.989922
# batch 386 d_loss : 0.563222
# batch 386 g_loss : 0.958300
# batch 387 d_loss : 0.524744
# batch 387 g_loss : 0.847180
# batch 388 d_loss : 0.511196
# batch 388 g_loss : 1.086631
# batch 389 d_loss : 0.496871
# batch 389 g_loss : 0.982658
# batch 390 d_loss : 0.446642
# batch 390 g_loss : 1.030953
# batch 391 d_loss : 0.478170
# batch 391 g_loss : 1.099404
# batch 392 d_loss : 0.466049
# batch 392 g_loss : 1.037561
# batch 393 d_loss : 0.524844
# batch 393 g_loss : 1.132784
# batch 394 d_loss : 0.412947
# batch 394 g_loss : 1.137563
# batch 395 d_loss : 0.591532
# batch 395 g_loss : 1.064698
# batch 396 d_loss : 0.518791
# batch 396 g_loss : 1.070143
# batch 397 d_loss : 0.526664
# batch 397 g_loss : 0.990239
# batch 398 d_loss : 0.600556
# batch 398 g_loss : 0.866967
# batch 399 d_loss : 0.471658
# batch 399 g_loss : 0.892695
# batch 400 d_loss : 0.558056
# batch 400 g_loss : 0.865542
# batch 401 d_loss : 0.523650
# batch 401 g_loss : 0.894691
# batch 402 d_loss : 0.508721
# batch 402 g_loss : 0.960466
# batch 403 d_loss : 0.547651
# batch 403 g_loss : 1.060500
# batch 404 d_loss : 0.465172
# batch 404 g_loss : 1.028867
# batch 405 d_loss : 0.514025
# batch 405 g_loss : 1.038136
# batch 406 d_loss : 0.511638
# batch 406 g_loss : 1.244553
# batch 407 d_loss : 0.482693
# batch 407 g_loss : 1.063311
# batch 408 d_loss : 0.483557
# batch 408 g_loss : 1.104195
# batch 409 d_loss : 0.465349
# batch 409 g_loss : 1.082146
# batch 410 d_loss : 0.515497
# batch 410 g_loss : 1.178868
# batch 411 d_loss : 0.538062
# batch 411 g_loss : 1.100345
# batch 412 d_loss : 0.513152
# batch 412 g_loss : 0.982910
# batch 413 d_loss : 0.552040
# batch 413 g_loss : 1.001133
# batch 414 d_loss : 0.575603
# batch 414 g_loss : 0.934236
# batch 415 d_loss : 0.564310
# batch 415 g_loss : 0.964557
# batch 416 d_loss : 0.486105
# batch 416 g_loss : 1.016521
# batch 417 d_loss : 0.559290
# batch 417 g_loss : 1.060222
# batch 418 d_loss : 0.485312
# batch 418 g_loss : 1.015537
# batch 419 d_loss : 0.475578
# batch 419 g_loss : 1.076378
# batch 420 d_loss : 0.506272
# batch 420 g_loss : 1.082934
# batch 421 d_loss : 0.470340
# batch 421 g_loss : 1.098318
# batch 422 d_loss : 0.570055
# batch 422 g_loss : 1.237139
# batch 423 d_loss : 0.462393
# batch 423 g_loss : 1.223647
# batch 424 d_loss : 0.443466
# batch 424 g_loss : 1.171870
# batch 425 d_loss : 0.567206
# batch 425 g_loss : 1.073579
# batch 426 d_loss : 0.612512
# batch 426 g_loss : 0.936301
# batch 427 d_loss : 0.550734
# batch 427 g_loss : 0.949793
# batch 428 d_loss : 0.627583
# batch 428 g_loss : 0.747253
# batch 429 d_loss : 0.532270
# batch 429 g_loss : 0.851661
# batch 430 d_loss : 0.522017
# batch 430 g_loss : 0.833371
# batch 431 d_loss : 0.529916
# batch 431 g_loss : 0.996997
# batch 432 d_loss : 0.538178
# batch 432 g_loss : 0.984968
# batch 433 d_loss : 0.555489
# batch 433 g_loss : 1.042314
# batch 434 d_loss : 0.592009
# batch 434 g_loss : 1.071157
# batch 435 d_loss : 0.503906
# batch 435 g_loss : 1.047965
# batch 436 d_loss : 0.532978
# batch 436 g_loss : 1.064513
# batch 437 d_loss : 0.575062
# batch 437 g_loss : 0.978043
# batch 438 d_loss : 0.583648
# batch 438 g_loss : 0.944350
# batch 439 d_loss : 0.545854
# batch 439 g_loss : 0.892774
# batch 440 d_loss : 0.598051
# batch 440 g_loss : 0.916311
# batch 441 d_loss : 0.566957
# batch 441 g_loss : 1.025586
# batch 442 d_loss : 0.593125
# batch 442 g_loss : 0.975456
# batch 443 d_loss : 0.490869
# batch 443 g_loss : 0.946529
# batch 444 d_loss : 0.589923
# batch 444 g_loss : 1.048624
# batch 445 d_loss : 0.520280
# batch 445 g_loss : 1.062336
# batch 446 d_loss : 0.532794
# batch 446 g_loss : 1.116782
# batch 447 d_loss : 0.598978
# batch 447 g_loss : 1.093716
# batch 448 d_loss : 0.526684
# batch 448 g_loss : 0.905466
# batch 449 d_loss : 0.541331
# batch 449 g_loss : 0.983882
# batch 450 d_loss : 0.535316
# batch 450 g_loss : 1.008352
# batch 451 d_loss : 0.515704
# batch 451 g_loss : 1.105096
# batch 452 d_loss : 0.529395
# batch 452 g_loss : 1.098683
# batch 453 d_loss : 0.553042
# batch 453 g_loss : 1.019673
# batch 454 d_loss : 0.519293
# batch 454 g_loss : 1.020024
# batch 455 d_loss : 0.542482
# batch 455 g_loss : 0.910317
# batch 456 d_loss : 0.544831
# batch 456 g_loss : 0.907691
# batch 457 d_loss : 0.579923
# batch 457 g_loss : 0.842383
# batch 458 d_loss : 0.549304
# batch 458 g_loss : 0.968528
# batch 459 d_loss : 0.528392
# batch 459 g_loss : 1.032270
# batch 460 d_loss : 0.581104
# batch 460 g_loss : 0.969159
# batch 461 d_loss : 0.587647
# batch 461 g_loss : 0.956386
# batch 462 d_loss : 0.623485
# batch 462 g_loss : 0.966768
# batch 463 d_loss : 0.540665
# batch 463 g_loss : 0.935149
# batch 464 d_loss : 0.500689
# batch 464 g_loss : 0.986218
# batch 465 d_loss : 0.479586
# batch 465 g_loss : 0.958206
# batch 466 d_loss : 0.475827
# batch 466 g_loss : 1.034124
# batch 467 d_loss : 0.525135
# batch 467 g_loss : 1.070810
# batch 468 d_loss : 0.451221
# batch 468 g_loss : 1.152877
# batch 469 d_loss : 0.439356
# batch 469 g_loss : 1.213623
# batch 470 d_loss : 0.507917
# batch 470 g_loss : 1.121426
# batch 471 d_loss : 0.484066
# batch 471 g_loss : 1.220279
# batch 472 d_loss : 0.494567
# batch 472 g_loss : 1.167759
# batch 473 d_loss : 0.501105
# batch 473 g_loss : 1.153617
# batch 474 d_loss : 0.524041
# batch 474 g_loss : 1.051697
# batch 475 d_loss : 0.450752
# batch 475 g_loss : 1.053459
# batch 476 d_loss : 0.498656
# batch 476 g_loss : 1.067448
# batch 477 d_loss : 0.523216
# batch 477 g_loss : 1.127947
# batch 478 d_loss : 0.444150
# batch 478 g_loss : 1.087674
# batch 479 d_loss : 0.446060
# batch 479 g_loss : 1.193773
# batch 480 d_loss : 0.479668
# batch 480 g_loss : 1.073950
# batch 481 d_loss : 0.572381
# batch 481 g_loss : 1.024001
# batch 482 d_loss : 0.517530
# batch 482 g_loss : 1.059690
# batch 483 d_loss : 0.432569
# batch 483 g_loss : 1.092689
# batch 484 d_loss : 0.522976
# batch 484 g_loss : 1.075174
# batch 485 d_loss : 0.488871
# batch 485 g_loss : 0.997252
# batch 486 d_loss : 0.556026
# batch 486 g_loss : 0.988523
# batch 487 d_loss : 0.485079
# batch 487 g_loss : 1.006335
# batch 488 d_loss : 0.470068
# batch 488 g_loss : 1.083304
# batch 489 d_loss : 0.502862
# batch 489 g_loss : 0.994009
# batch 490 d_loss : 0.454325
# batch 490 g_loss : 1.064802
# batch 491 d_loss : 0.553456
# batch 491 g_loss : 1.081733
# batch 492 d_loss : 0.445394
# batch 492 g_loss : 1.154566
# batch 493 d_loss : 0.529282
# batch 493 g_loss : 1.191766
# batch 494 d_loss : 0.575549
# batch 494 g_loss : 1.081321
# batch 495 d_loss : 0.489755
# batch 495 g_loss : 1.112615
# batch 496 d_loss : 0.568186
# batch 496 g_loss : 1.018811
# batch 497 d_loss : 0.617310
# batch 497 g_loss : 0.992139
# batch 498 d_loss : 0.610570
# batch 498 g_loss : 0.931838
# batch 499 d_loss : 0.530797
# batch 499 g_loss : 0.972361
# batch 500 d_loss : 0.532955
# batch 500 g_loss : 1.089746
# batch 501 d_loss : 0.533411
# batch 501 g_loss : 1.074828
# batch 502 d_loss : 0.549448
# batch 502 g_loss : 1.101989
# batch 503 d_loss : 0.554209
# batch 503 g_loss : 1.151605
# batch 504 d_loss : 0.481787
# batch 504 g_loss : 1.099424
# batch 505 d_loss : 0.480715
# batch 505 g_loss : 1.171677
# batch 506 d_loss : 0.498879
# batch 506 g_loss : 1.067999
# batch 507 d_loss : 0.469855
# batch 507 g_loss : 1.168148
# batch 508 d_loss : 0.469272
# batch 508 g_loss : 1.147055
# batch 509 d_loss : 0.471969
# batch 509 g_loss : 1.006525
# batch 510 d_loss : 0.456309
# batch 510 g_loss : 1.149099
# batch 511 d_loss : 0.493529
# batch 511 g_loss : 1.207278
# batch 512 d_loss : 0.462898
# batch 512 g_loss : 1.232086
# batch 513 d_loss : 0.447832
# batch 513 g_loss : 1.230145
# batch 514 d_loss : 0.449850
# batch 514 g_loss : 1.252528
# batch 515 d_loss : 0.475830
# batch 515 g_loss : 1.111104
# batch 516 d_loss : 0.467677
# batch 516 g_loss : 1.148188
# batch 517 d_loss : 0.432027
# batch 517 g_loss : 1.141242
# batch 518 d_loss : 0.428808
# batch 518 g_loss : 1.067373
# batch 519 d_loss : 0.447186
# batch 519 g_loss : 1.041957
# batch 520 d_loss : 0.457645
# batch 520 g_loss : 1.077751
# batch 521 d_loss : 0.452044
# batch 521 g_loss : 1.000695
# batch 522 d_loss : 0.492592
# batch 522 g_loss : 1.111332
# batch 523 d_loss : 0.496193
# batch 523 g_loss : 1.111620
# batch 524 d_loss : 0.488916
# batch 524 g_loss : 1.136805
# batch 525 d_loss : 0.513600
# batch 525 g_loss : 1.097213
# batch 526 d_loss : 0.530833
# batch 526 g_loss : 0.973446
# batch 527 d_loss : 0.524834
# batch 527 g_loss : 0.990800
# batch 528 d_loss : 0.497015
# batch 528 g_loss : 0.913438
# batch 529 d_loss : 0.532521
# batch 529 g_loss : 0.839759
# batch 530 d_loss : 0.533294
# batch 530 g_loss : 0.907060
# batch 531 d_loss : 0.498553
# batch 531 g_loss : 1.154478
# batch 532 d_loss : 0.524281
# batch 532 g_loss : 1.048728
# batch 533 d_loss : 0.485523
# batch 533 g_loss : 1.113213
# batch 534 d_loss : 0.448569
# batch 534 g_loss : 1.199049
# batch 535 d_loss : 0.575089
# batch 535 g_loss : 1.178594
# batch 536 d_loss : 0.491853
# batch 536 g_loss : 1.055989
# batch 537 d_loss : 0.565716
# batch 537 g_loss : 1.042248
# batch 538 d_loss : 0.506327
# batch 538 g_loss : 1.078875
# batch 539 d_loss : 0.505540
# batch 539 g_loss : 0.927257
# batch 540 d_loss : 0.468300
# batch 540 g_loss : 1.036096
# batch 541 d_loss : 0.529008
# batch 541 g_loss : 1.142218
# batch 542 d_loss : 0.460927
# batch 542 g_loss : 1.177964
# batch 543 d_loss : 0.487952
# batch 543 g_loss : 1.118077
# batch 544 d_loss : 0.571436
# batch 544 g_loss : 1.041893
# batch 545 d_loss : 0.503795
# batch 545 g_loss : 1.135903
# batch 546 d_loss : 0.551114
# batch 546 g_loss : 1.210243
# batch 547 d_loss : 0.552268
# batch 547 g_loss : 1.062016
# batch 548 d_loss : 0.589770
# batch 548 g_loss : 0.984334
# batch 549 d_loss : 0.542706
# batch 549 g_loss : 1.105358
# batch 550 d_loss : 0.575251
# batch 550 g_loss : 0.915039
# batch 551 d_loss : 0.591770
# batch 551 g_loss : 0.980310
# batch 552 d_loss : 0.561326
# batch 552 g_loss : 0.967931
# batch 553 d_loss : 0.430189
# batch 553 g_loss : 1.072538
# batch 554 d_loss : 0.536871
# batch 554 g_loss : 1.129436
# batch 555 d_loss : 0.484465
# batch 555 g_loss : 1.128651
# batch 556 d_loss : 0.465023
# batch 556 g_loss : 1.295978
# batch 557 d_loss : 0.516564
# batch 557 g_loss : 1.144550
# batch 558 d_loss : 0.489237
# batch 558 g_loss : 1.047186
# batch 559 d_loss : 0.437188
# batch 559 g_loss : 1.065323
# batch 560 d_loss : 0.514421
# batch 560 g_loss : 1.074544
# batch 561 d_loss : 0.480224
# batch 561 g_loss : 1.116244
# batch 562 d_loss : 0.428996
# batch 562 g_loss : 1.229207
# batch 563 d_loss : 0.499312
# batch 563 g_loss : 1.170930
# batch 564 d_loss : 0.511167
# batch 564 g_loss : 1.218851
# batch 565 d_loss : 0.420465
# batch 565 g_loss : 1.209430
# batch 566 d_loss : 0.463468
# batch 566 g_loss : 1.176461
# batch 567 d_loss : 0.412411
# batch 567 g_loss : 1.205239
# batch 568 d_loss : 0.551815
# batch 568 g_loss : 1.233558
# batch 569 d_loss : 0.489623
# batch 569 g_loss : 1.341061
# batch 570 d_loss : 0.511962
# batch 570 g_loss : 1.057209
# batch 571 d_loss : 0.451159
# batch 571 g_loss : 1.081500
# batch 572 d_loss : 0.431712
# batch 572 g_loss : 1.145309
# batch 573 d_loss : 0.432057
# batch 573 g_loss : 1.174902
# batch 574 d_loss : 0.433583
# batch 574 g_loss : 1.189128
# batch 575 d_loss : 0.453877
# batch 575 g_loss : 1.152366
# batch 576 d_loss : 0.405587
# batch 576 g_loss : 1.219257
# batch 577 d_loss : 0.440276
# batch 577 g_loss : 1.159896
# batch 578 d_loss : 0.501453
# batch 578 g_loss : 1.131988
# batch 579 d_loss : 0.471460
# batch 579 g_loss : 1.087193
# batch 580 d_loss : 0.466443
# batch 580 g_loss : 1.062615
# batch 581 d_loss : 0.465599
# batch 581 g_loss : 1.113360
# batch 582 d_loss : 0.425222
# batch 582 g_loss : 1.242953
# batch 583 d_loss : 0.495754
# batch 583 g_loss : 1.202523
# batch 584 d_loss : 0.435069
# batch 584 g_loss : 1.237306
# batch 585 d_loss : 0.474788
# batch 585 g_loss : 1.219583
# batch 586 d_loss : 0.422163
# batch 586 g_loss : 1.189066
# batch 587 d_loss : 0.416938
# batch 587 g_loss : 1.156900
# batch 588 d_loss : 0.487212
# batch 588 g_loss : 1.079661
# batch 589 d_loss : 0.483755
# batch 589 g_loss : 1.098948
# batch 590 d_loss : 0.504567
# batch 590 g_loss : 1.237285
# batch 591 d_loss : 0.488726
# batch 591 g_loss : 1.207031
# batch 592 d_loss : 0.438409
# batch 592 g_loss : 1.151663
# batch 593 d_loss : 0.519042
# batch 593 g_loss : 1.169314
# batch 594 d_loss : 0.449229
# batch 594 g_loss : 1.184584
# batch 595 d_loss : 0.532226
# batch 595 g_loss : 1.043911
# batch 596 d_loss : 0.492526
# batch 596 g_loss : 0.978965
# batch 597 d_loss : 0.386988
# batch 597 g_loss : 1.111484
# batch 598 d_loss : 0.460791
# batch 598 g_loss : 1.083981
# batch 599 d_loss : 0.480695
# batch 599 g_loss : 1.143752
# batch 600 d_loss : 0.524927
# batch 600 g_loss : 1.166093
# batch 601 d_loss : 0.460971
# batch 601 g_loss : 1.297674
# batch 602 d_loss : 0.512146
# batch 602 g_loss : 1.150487
# batch 603 d_loss : 0.533260
# batch 603 g_loss : 1.110017
# batch 604 d_loss : 0.480549
# batch 604 g_loss : 1.079154
# batch 605 d_loss : 0.537146
# batch 605 g_loss : 1.128096
# batch 606 d_loss : 0.505567
# batch 606 g_loss : 1.244106
# batch 607 d_loss : 0.463311
# batch 607 g_loss : 1.155816
# batch 608 d_loss : 0.448523
# batch 608 g_loss : 1.208422
# batch 609 d_loss : 0.474382
# batch 609 g_loss : 1.207161
# batch 610 d_loss : 0.490139
# batch 610 g_loss : 1.394354
# batch 611 d_loss : 0.420154
# batch 611 g_loss : 1.146855
# batch 612 d_loss : 0.356967
# batch 612 g_loss : 1.297776
# batch 613 d_loss : 0.429685
# batch 613 g_loss : 1.385126
# batch 614 d_loss : 0.423202
# batch 614 g_loss : 1.284010
# batch 615 d_loss : 0.427680
# batch 615 g_loss : 1.201006
# batch 616 d_loss : 0.415646
# batch 616 g_loss : 1.323831
# batch 617 d_loss : 0.383516
# batch 617 g_loss : 1.319334
# batch 618 d_loss : 0.386933
# batch 618 g_loss : 1.289766
# batch 619 d_loss : 0.402104
# batch 619 g_loss : 1.458496
# batch 620 d_loss : 0.416010
# batch 620 g_loss : 1.278896
# batch 621 d_loss : 0.482472
# batch 621 g_loss : 1.129197
# batch 622 d_loss : 0.456840
# batch 622 g_loss : 1.128924
# batch 623 d_loss : 0.540970
# batch 623 g_loss : 1.083550
# batch 624 d_loss : 0.485528
# batch 624 g_loss : 1.092484
# batch 625 d_loss : 0.461540
# batch 625 g_loss : 1.082977
# batch 626 d_loss : 0.549219
# batch 626 g_loss : 1.163105
# batch 627 d_loss : 0.444244
# batch 627 g_loss : 1.276116
# batch 628 d_loss : 0.411176
# batch 628 g_loss : 1.026002
# batch 629 d_loss : 0.532620
# batch 629 g_loss : 1.226371
# batch 630 d_loss : 0.446323
# batch 630 g_loss : 1.231488
# batch 631 d_loss : 0.433690
# batch 631 g_loss : 1.296231
# batch 632 d_loss : 0.438085
# batch 632 g_loss : 1.251502
# batch 633 d_loss : 0.555161
# batch 633 g_loss : 1.062386
# batch 634 d_loss : 0.480558
# batch 634 g_loss : 1.090666
# batch 635 d_loss : 0.497115
# batch 635 g_loss : 1.113935
# batch 636 d_loss : 0.437335
# batch 636 g_loss : 1.062113
# batch 637 d_loss : 0.439224
# batch 637 g_loss : 1.109971
# batch 638 d_loss : 0.409361
# batch 638 g_loss : 1.328794
# batch 639 d_loss : 0.501538
# batch 639 g_loss : 1.337120
# batch 640 d_loss : 0.374422
# batch 640 g_loss : 1.253529
# batch 641 d_loss : 0.414668
# batch 641 g_loss : 1.396507
# batch 642 d_loss : 0.379199
# batch 642 g_loss : 1.312224
# batch 643 d_loss : 0.413711
# batch 643 g_loss : 1.184810
# batch 644 d_loss : 0.389441
# batch 644 g_loss : 1.225828
# batch 645 d_loss : 0.416480
# batch 645 g_loss : 1.354661
# batch 646 d_loss : 0.405479
# batch 646 g_loss : 1.449097
# batch 647 d_loss : 0.411946
# batch 647 g_loss : 1.190276
# batch 648 d_loss : 0.395057
# batch 648 g_loss : 1.248892
# batch 649 d_loss : 0.424059
# batch 649 g_loss : 1.256340
# batch 650 d_loss : 0.403321
# batch 650 g_loss : 1.264386
# batch 651 d_loss : 0.543989
# batch 651 g_loss : 1.144518
# batch 652 d_loss : 0.470899
# batch 652 g_loss : 1.016128
# batch 653 d_loss : 0.472670
# batch 653 g_loss : 1.081264
# batch 654 d_loss : 0.455789
# batch 654 g_loss : 1.254678
# batch 655 d_loss : 0.530983
# batch 655 g_loss : 0.998367
# batch 656 d_loss : 0.455929
# batch 656 g_loss : 1.138416
# batch 657 d_loss : 0.419440
# batch 657 g_loss : 1.342453
# batch 658 d_loss : 0.400720
# batch 658 g_loss : 1.149521
# batch 659 d_loss : 0.471943
# batch 659 g_loss : 1.255573
# batch 660 d_loss : 0.455665
# batch 660 g_loss : 1.314337
# batch 661 d_loss : 0.381716
# batch 661 g_loss : 1.255501
# batch 662 d_loss : 0.392016
# batch 662 g_loss : 1.284033
# batch 663 d_loss : 0.419650
# batch 663 g_loss : 1.365017
# batch 664 d_loss : 0.416571
# batch 664 g_loss : 1.419413
# batch 665 d_loss : 0.415628
# batch 665 g_loss : 1.319672
# batch 666 d_loss : 0.419309
# batch 666 g_loss : 1.196471
# batch 667 d_loss : 0.437443
# batch 667 g_loss : 1.260769
# batch 668 d_loss : 0.400066
# batch 668 g_loss : 1.250419
# batch 669 d_loss : 0.432771
# batch 669 g_loss : 1.153306
# batch 670 d_loss : 0.419585
# batch 670 g_loss : 1.334198
# batch 671 d_loss : 0.363524
# batch 671 g_loss : 1.173869
# batch 672 d_loss : 0.361398
# batch 672 g_loss : 1.403693
# batch 673 d_loss : 0.411392
# batch 673 g_loss : 1.401680
# batch 674 d_loss : 0.341035
# batch 674 g_loss : 1.375913
# batch 675 d_loss : 0.406638
# batch 675 g_loss : 1.346393
# batch 676 d_loss : 0.372360
# batch 676 g_loss : 1.246237
# batch 677 d_loss : 0.379086
# batch 677 g_loss : 1.424686
# batch 678 d_loss : 0.413944
# batch 678 g_loss : 1.239879
# batch 679 d_loss : 0.451235
# batch 679 g_loss : 1.247715
# batch 680 d_loss : 0.455797
# batch 680 g_loss : 1.214621
# batch 681 d_loss : 0.448151
# batch 681 g_loss : 1.278183
# batch 682 d_loss : 0.385396
# batch 682 g_loss : 1.354393
# batch 683 d_loss : 0.367300
# batch 683 g_loss : 1.401414
# batch 684 d_loss : 0.405670
# batch 684 g_loss : 1.473630
# batch 685 d_loss : 0.485780
# batch 685 g_loss : 1.315499
# batch 686 d_loss : 0.405974
# batch 686 g_loss : 1.532395
# batch 687 d_loss : 0.394276
# batch 687 g_loss : 1.404606
# batch 688 d_loss : 0.478281
# batch 688 g_loss : 1.261278
# batch 689 d_loss : 0.444368
# batch 689 g_loss : 1.201307
# batch 690 d_loss : 0.494562
# batch 690 g_loss : 1.138050
# batch 691 d_loss : 0.474125
# batch 691 g_loss : 1.137168
# batch 692 d_loss : 0.426778
# batch 692 g_loss : 1.010107
# batch 693 d_loss : 0.479545
# batch 693 g_loss : 1.156374
# batch 694 d_loss : 0.411337
# batch 694 g_loss : 1.374054
# batch 695 d_loss : 0.438823
# batch 695 g_loss : 1.373619
# batch 696 d_loss : 0.374359
# batch 696 g_loss : 1.403044
# batch 697 d_loss : 0.364208
# batch 697 g_loss : 1.371275
# batch 698 d_loss : 0.422235
# batch 698 g_loss : 1.317361
# batch 699 d_loss : 0.395235
# batch 699 g_loss : 1.353855
# batch 700 d_loss : 0.428321
# batch 700 g_loss : 1.338311
# batch 701 d_loss : 0.406380
# batch 701 g_loss : 1.172960
# batch 702 d_loss : 0.495609
# batch 702 g_loss : 1.162167
# batch 703 d_loss : 0.490778
# batch 703 g_loss : 1.003415
# batch 704 d_loss : 0.564655
# batch 704 g_loss : 0.871832
# batch 705 d_loss : 0.494592
# batch 705 g_loss : 1.105742
# batch 706 d_loss : 0.500298
# batch 706 g_loss : 1.135770
# batch 707 d_loss : 0.495066
# batch 707 g_loss : 1.171808
# batch 708 d_loss : 0.522048
# batch 708 g_loss : 1.201177
# batch 709 d_loss : 0.473477
# batch 709 g_loss : 1.373587
# batch 710 d_loss : 0.437672
# batch 710 g_loss : 1.336955
# batch 711 d_loss : 0.512795
# batch 711 g_loss : 1.289834
# batch 712 d_loss : 0.476363
# batch 712 g_loss : 1.245469
# batch 713 d_loss : 0.442084
# batch 713 g_loss : 1.113968
# batch 714 d_loss : 0.421651
# batch 714 g_loss : 1.135001
# batch 715 d_loss : 0.423519
# batch 715 g_loss : 1.130437
# batch 716 d_loss : 0.506260
# batch 716 g_loss : 1.151779
# batch 717 d_loss : 0.413791
# batch 717 g_loss : 1.277012
# batch 718 d_loss : 0.451493
# batch 718 g_loss : 1.214172
# batch 719 d_loss : 0.437392
# batch 719 g_loss : 1.385707
# batch 720 d_loss : 0.434779
# batch 720 g_loss : 1.268514
# batch 721 d_loss : 0.435535
# batch 721 g_loss : 1.416680
# batch 722 d_loss : 0.421281
# batch 722 g_loss : 1.324319
# batch 723 d_loss : 0.439754
# batch 723 g_loss : 1.233565
# batch 724 d_loss : 0.429980
# batch 724 g_loss : 1.381380
# batch 725 d_loss : 0.444375
# batch 725 g_loss : 1.289999
# batch 726 d_loss : 0.397923
# batch 726 g_loss : 1.290728
# batch 727 d_loss : 0.425842
# batch 727 g_loss : 1.352005
# batch 728 d_loss : 0.421042
# batch 728 g_loss : 1.353366
# batch 729 d_loss : 0.493359
# batch 729 g_loss : 1.156059
# batch 730 d_loss : 0.428948
# batch 730 g_loss : 1.114474
# batch 731 d_loss : 0.439011
# batch 731 g_loss : 1.244608
# batch 732 d_loss : 0.456608
# batch 732 g_loss : 1.177134
# batch 733 d_loss : 0.445022
# batch 733 g_loss : 1.330315
# batch 734 d_loss : 0.434982
# batch 734 g_loss : 1.241214
# batch 735 d_loss : 0.373745
# batch 735 g_loss : 1.121655
# batch 736 d_loss : 0.444526
# batch 736 g_loss : 1.098056
# batch 737 d_loss : 0.400048
# batch 737 g_loss : 1.040457
# batch 738 d_loss : 0.383020
# batch 738 g_loss : 0.914203
# batch 739 d_loss : 0.477191
# batch 739 g_loss : 1.124367
# batch 740 d_loss : 0.490132
# batch 740 g_loss : 1.059337
# batch 741 d_loss : 0.458572
# batch 741 g_loss : 1.111759
# batch 742 d_loss : 0.453422
# batch 742 g_loss : 1.133462
# batch 743 d_loss : 0.438441
# batch 743 g_loss : 1.215382
# batch 744 d_loss : 0.399622
# batch 744 g_loss : 1.478323
# batch 745 d_loss : 0.435641
# batch 745 g_loss : 1.344877
# batch 746 d_loss : 0.575719
# batch 746 g_loss : 1.197494
# batch 747 d_loss : 0.374432
# batch 747 g_loss : 1.200357
# batch 748 d_loss : 0.403246
# batch 748 g_loss : 1.182997
# batch 749 d_loss : 0.390731
# batch 749 g_loss : 1.345110
# batch 750 d_loss : 0.470034
# batch 750 g_loss : 1.253316
# batch 751 d_loss : 0.351470
# batch 751 g_loss : 1.327123
# batch 752 d_loss : 0.374779
# batch 752 g_loss : 1.318510
# batch 753 d_loss : 0.368863
# batch 753 g_loss : 1.464014
# batch 754 d_loss : 0.419003
# batch 754 g_loss : 1.406382
# batch 755 d_loss : 0.374543
# batch 755 g_loss : 1.311046
# batch 756 d_loss : 0.444028
# batch 756 g_loss : 1.220539
# batch 757 d_loss : 0.465552
# batch 757 g_loss : 1.234674
# batch 758 d_loss : 0.457810
# batch 758 g_loss : 1.205974
# batch 759 d_loss : 0.404713
# batch 759 g_loss : 1.294503
# batch 760 d_loss : 0.443024
# batch 760 g_loss : 1.196562
# batch 761 d_loss : 0.422343
# batch 761 g_loss : 1.191675
# batch 762 d_loss : 0.383426
# batch 762 g_loss : 1.157084
# batch 763 d_loss : 0.402382
# batch 763 g_loss : 1.298836
# batch 764 d_loss : 0.475508
# batch 764 g_loss : 1.319478
# batch 765 d_loss : 0.387870
# batch 765 g_loss : 1.150745
# batch 766 d_loss : 0.530922
# batch 766 g_loss : 1.260087
# batch 767 d_loss : 0.391492
# batch 767 g_loss : 1.329145
# batch 768 d_loss : 0.413709
# batch 768 g_loss : 1.249239
# batch 769 d_loss : 0.496633
# batch 769 g_loss : 1.191603
# batch 770 d_loss : 0.409984
# batch 770 g_loss : 1.152169
# batch 771 d_loss : 0.424749
# batch 771 g_loss : 1.517761
# batch 772 d_loss : 0.400266
# batch 772 g_loss : 1.531322
# batch 773 d_loss : 0.400399
# batch 773 g_loss : 1.381343
# batch 774 d_loss : 0.370482
# batch 774 g_loss : 1.307884
# batch 775 d_loss : 0.351596
# batch 775 g_loss : 1.471572
# batch 776 d_loss : 0.406017
# batch 776 g_loss : 1.356631
# batch 777 d_loss : 0.398661
# batch 777 g_loss : 1.143895
# batch 778 d_loss : 0.423129
# batch 778 g_loss : 1.117020
# batch 779 d_loss : 0.466836
# batch 779 g_loss : 1.096945
# batch 780 d_loss : 0.443162
# batch 780 g_loss : 0.947143
# batch 781 d_loss : 0.391187
# batch 781 g_loss : 1.196023
# batch 782 d_loss : 0.401980
# batch 782 g_loss : 1.245623
# batch 783 d_loss : 0.397278
# batch 783 g_loss : 1.150758
# batch 784 d_loss : 0.345497
# batch 784 g_loss : 1.257715
# batch 785 d_loss : 0.388184
# batch 785 g_loss : 1.269835
# batch 786 d_loss : 0.386380
# batch 786 g_loss : 1.099374
# batch 787 d_loss : 0.397947
# batch 787 g_loss : 1.335843
# batch 788 d_loss : 0.370002
# batch 788 g_loss : 1.279678
# batch 789 d_loss : 0.418997
# batch 789 g_loss : 1.283798
# batch 790 d_loss : 0.488576
# batch 790 g_loss : 1.231176
# batch 791 d_loss : 0.510592
# batch 791 g_loss : 1.215912
# batch 792 d_loss : 0.414086
# batch 792 g_loss : 1.225560
# batch 793 d_loss : 0.419036
# batch 793 g_loss : 1.307387
# batch 794 d_loss : 0.457148
# batch 794 g_loss : 1.294383
# batch 795 d_loss : 0.417706
# batch 795 g_loss : 1.409734
# batch 796 d_loss : 0.483353
# batch 796 g_loss : 1.391745
# batch 797 d_loss : 0.394584
# batch 797 g_loss : 1.339025
# batch 798 d_loss : 0.386892
# batch 798 g_loss : 1.290834
# batch 799 d_loss : 0.400891
# batch 799 g_loss : 1.216707
# batch 800 d_loss : 0.376713
# batch 800 g_loss : 1.290336
# batch 801 d_loss : 0.391094
# batch 801 g_loss : 1.313841
# batch 802 d_loss : 0.457110
# batch 802 g_loss : 1.273188
# batch 803 d_loss : 0.407105
# batch 803 g_loss : 1.225401
# batch 804 d_loss : 0.385038
# batch 804 g_loss : 1.069090
# batch 805 d_loss : 0.365442
# batch 805 g_loss : 1.219227
# batch 806 d_loss : 0.386140
# batch 806 g_loss : 1.063425
# batch 807 d_loss : 0.412794
# batch 807 g_loss : 1.115786
# batch 808 d_loss : 0.386088
# batch 808 g_loss : 1.120505
# batch 809 d_loss : 0.413133
# batch 809 g_loss : 1.140490
# batch 810 d_loss : 0.373824
# batch 810 g_loss : 1.225198
# batch 811 d_loss : 0.414469
# batch 811 g_loss : 1.237797
# batch 812 d_loss : 0.411671
# batch 812 g_loss : 1.213922
# batch 813 d_loss : 0.336178
# batch 813 g_loss : 1.283635
# batch 814 d_loss : 0.449486
# batch 814 g_loss : 1.382785
# batch 815 d_loss : 0.388859
# batch 815 g_loss : 1.233067
# batch 816 d_loss : 0.370287
# batch 816 g_loss : 1.477657
# batch 817 d_loss : 0.438372
# batch 817 g_loss : 1.209273
# batch 818 d_loss : 0.424474
# batch 818 g_loss : 1.322114
# batch 819 d_loss : 0.381358
# batch 819 g_loss : 1.408486
# batch 820 d_loss : 0.486300
# batch 820 g_loss : 1.276610
# batch 821 d_loss : 0.390926
# batch 821 g_loss : 1.265423
# batch 822 d_loss : 0.356958
# batch 822 g_loss : 1.419687
# batch 823 d_loss : 0.427150
# batch 823 g_loss : 1.261248
# batch 824 d_loss : 0.373516
# batch 824 g_loss : 1.390587
# batch 825 d_loss : 0.383141
# batch 825 g_loss : 1.185770
# batch 826 d_loss : 0.445819
# batch 826 g_loss : 1.289774
# batch 827 d_loss : 0.370170
# batch 827 g_loss : 1.064443
# batch 828 d_loss : 0.378370
# batch 828 g_loss : 1.011544
# batch 829 d_loss : 0.502328
# batch 829 g_loss : 1.152533
# batch 830 d_loss : 0.508221
# batch 830 g_loss : 1.196311
# batch 831 d_loss : 0.454151
# batch 831 g_loss : 1.333065
# batch 832 d_loss : 0.434638
# batch 832 g_loss : 1.332059
# batch 833 d_loss : 0.451698
# batch 833 g_loss : 1.304841
# batch 834 d_loss : 0.336343
# batch 834 g_loss : 1.399709
# batch 835 d_loss : 0.385717
# batch 835 g_loss : 1.449427
# batch 836 d_loss : 0.436502
# batch 836 g_loss : 1.485687
# batch 837 d_loss : 0.404425
# batch 837 g_loss : 1.370991
# batch 838 d_loss : 0.334773
# batch 838 g_loss : 1.572304
# batch 839 d_loss : 0.408436
# batch 839 g_loss : 1.659069
# batch 840 d_loss : 0.413726
# batch 840 g_loss : 1.488010
# batch 841 d_loss : 0.361953
# batch 841 g_loss : 1.273346
# batch 842 d_loss : 0.318455
# batch 842 g_loss : 1.398227
# batch 843 d_loss : 0.377297
# batch 843 g_loss : 1.471686
# batch 844 d_loss : 0.379767
# batch 844 g_loss : 1.391613
# batch 845 d_loss : 0.372179
# batch 845 g_loss : 1.358317
# batch 846 d_loss : 0.440955
# batch 846 g_loss : 1.324854
# batch 847 d_loss : 0.437222
# batch 847 g_loss : 1.194938
# batch 848 d_loss : 0.457541
# batch 848 g_loss : 1.509122
# batch 849 d_loss : 0.473821
# batch 849 g_loss : 1.155059
# batch 850 d_loss : 0.480962
# batch 850 g_loss : 1.063617
# batch 851 d_loss : 0.365125
# batch 851 g_loss : 1.201449
# batch 852 d_loss : 0.490338
# batch 852 g_loss : 1.180380
# batch 853 d_loss : 0.481718
# batch 853 g_loss : 1.317120
# batch 854 d_loss : 0.511118
# batch 854 g_loss : 1.342164
# batch 855 d_loss : 0.366240
# batch 855 g_loss : 1.106152
# batch 856 d_loss : 0.388623
# batch 856 g_loss : 1.361544
# batch 857 d_loss : 0.437044
# ...
# batch 1431 g_loss : 1.468523
# batch 1432 d_loss : 0.439281
# batch 1432 g_loss : 1.982221
# batch 1433 d_loss : 0.362976
# batch 1433 g_loss : 1.182546
# batch 1434 d_loss : 0.372086
# batch 1434 g_loss : 1.181782
# batch 1435 d_loss : 0.410530
# batch 1435 g_loss : 1.170678
# batch 1436 d_loss : 0.454838
# batch 1436 g_loss : 1.151257
# batch 1437 d_loss : 0.426515
# batch 1437 g_loss : 1.149547
# batch 1438 d_loss : 0.493554
# batch 1438 g_loss : 1.267654
# batch 1439 d_loss : 0.354128
# batch 1439 g_loss : 1.878419
# batch 1440 d_loss : 0.455477
# batch 1440 g_loss : 0.732503
# batch 1441 d_loss : 0.541272
# batch 1441 g_loss : 3.209302
# batch 1442 d_loss : 0.516090
# batch 1442 g_loss : 1.079570
# batch 1443 d_loss : 0.383450
# batch 1443 g_loss : 1.936340
# batch 1444 d_loss : 0.307544
# batch 1444 g_loss : 1.692275
# batch 1445 d_loss : 0.344440
# batch 1445 g_loss : 1.566607
# batch 1446 d_loss : 0.354261
# batch 1446 g_loss : 1.415291
# batch 1447 d_loss : 0.331900
# batch 1447 g_loss : 1.530679
# batch 1448 d_loss : 0.467460
# batch 1448 g_loss : 1.542554
# batch 1449 d_loss : 0.335379
# batch 1449 g_loss : 1.665699
# batch 1450 d_loss : 0.309391
# batch 1450 g_loss : 1.508878
# batch 1451 d_loss : 0.469837
# batch 1451 g_loss : 0.801350
# batch 1452 d_loss : 0.478939
# batch 1452 g_loss : 2.775549
# batch 1453 d_loss : 0.455520
# batch 1453 g_loss : 0.861620
# batch 1454 d_loss : 0.512633
# batch 1454 g_loss : 2.398924
# batch 1455 d_loss : 0.363520
# batch 1455 g_loss : 1.095045
# batch 1456 d_loss : 0.418235
# batch 1456 g_loss : 2.342868
# batch 1457 d_loss : 0.425007
# batch 1457 g_loss : 1.186111
# batch 1458 d_loss : 0.453616
# batch 1458 g_loss : 2.597974
# batch 1459 d_loss : 0.541624
# batch 1459 g_loss : 1.473088
# batch 1460 d_loss : 0.361117
# batch 1460 g_loss : 2.294773
# batch 1461 d_loss : 0.311333
# batch 1461 g_loss : 1.546070
# batch 1462 d_loss : 0.275111
# batch 1462 g_loss : 1.815044
# batch 1463 d_loss : 0.313860
# batch 1463 g_loss : 1.583546
# batch 1464 d_loss : 0.350519
# batch 1464 g_loss : 1.807362
# batch 1465 d_loss : 0.259298
# batch 1465 g_loss : 1.615996
# batch 1466 d_loss : 0.546443
# batch 1466 g_loss : 1.206568
# batch 1467 d_loss : 0.461566
# batch 1467 g_loss : 2.259562
# batch 1468 d_loss : 0.627434
# batch 1468 g_loss : 1.075146
# batch 1469 d_loss : 0.521742
# batch 1469 g_loss : 1.295785
# batch 1470 d_loss : 0.503843
# batch 1470 g_loss : 1.802266
# batch 1471 d_loss : 0.440242
# batch 1471 g_loss : 1.082002
# batch 1472 d_loss : 0.480062
# batch 1472 g_loss : 1.627398
# batch 1473 d_loss : 0.432457
# batch 1473 g_loss : 1.516498
# batch 1474 d_loss : 0.380299
# batch 1474 g_loss : 1.095257
# batch 1475 d_loss : 0.460693
# batch 1475 g_loss : 1.353314
# batch 1476 d_loss : 0.458656
# batch 1476 g_loss : 0.884523
# batch 1477 d_loss : 0.410753
# batch 1477 g_loss : 1.882801
# batch 1478 d_loss : 0.342675
# batch 1478 g_loss : 1.696395
# batch 1479 d_loss : 0.269871
# batch 1479 g_loss : 1.534948
# batch 1480 d_loss : 0.614876
# batch 1480 g_loss : 0.821838
# batch 1481 d_loss : 0.531564
# batch 1481 g_loss : 1.159352
# batch 1482 d_loss : 0.587924
# batch 1482 g_loss : 1.221395
# batch 1483 d_loss : 0.469215
# batch 1483 g_loss : 1.390777
# batch 1484 d_loss : 0.463938
# batch 1484 g_loss : 1.662843
# batch 1485 d_loss : 0.563876
# batch 1485 g_loss : 0.970756
# batch 1486 d_loss : 0.568214
# batch 1486 g_loss : 1.765934
# batch 1487 d_loss : 0.686233
# batch 1487 g_loss : 0.971171
# batch 1488 d_loss : 0.567576
# batch 1488 g_loss : 1.994124
# batch 1489 d_loss : 0.685750
# batch 1489 g_loss : 1.212259
# batch 1490 d_loss : 0.440938
# batch 1490 g_loss : 1.403110
# batch 1491 d_loss : 0.383432
# batch 1491 g_loss : 1.486329
# batch 1492 d_loss : 0.382870
# batch 1492 g_loss : 1.478818
# batch 1493 d_loss : 0.386403
# batch 1493 g_loss : 1.000360
# batch 1494 d_loss : 0.409562
# batch 1494 g_loss : 1.957152
# batch 1495 d_loss : 0.464983
# batch 1495 g_loss : 1.069138
# batch 1496 d_loss : 0.409992
# batch 1496 g_loss : 1.768747
# batch 1497 d_loss : 0.479509
# batch 1497 g_loss : 1.093394
# batch 1498 d_loss : 0.580241
# batch 1498 g_loss : 0.997505
# batch 1499 d_loss : 0.413955
# batch 1499 g_loss : 1.554498
# batch 1500 d_loss : 0.330951
# batch 1500 g_loss : 1.787692
# batch 1501 d_loss : 0.574073
# batch 1501 g_loss : 1.060043
# batch 1502 d_loss : 0.517303
# batch 1502 g_loss : 2.277822
# batch 1503 d_loss : 0.516065
# batch 1503 g_loss : 0.845309
# batch 1504 d_loss : 0.444864
# batch 1504 g_loss : 1.818788
# batch 1505 d_loss : 0.456125
# batch 1505 g_loss : 1.054788
# batch 1506 d_loss : 0.382723
# batch 1506 g_loss : 1.822710
# batch 1507 d_loss : 0.491094
# batch 1507 g_loss : 0.931959
# batch 1508 d_loss : 0.514402
# batch 1508 g_loss : 1.637335
# batch 1509 d_loss : 0.421641
# batch 1509 g_loss : 1.006000
# batch 1510 d_loss : 0.449028
# batch 1510 g_loss : 1.237032
# batch 1511 d_loss : 0.371950
# batch 1511 g_loss : 1.192124
# batch 1512 d_loss : 0.382048
# batch 1512 g_loss : 1.442682
# batch 1513 d_loss : 0.428811
# batch 1513 g_loss : 0.951943
# batch 1514 d_loss : 0.356023
# batch 1514 g_loss : 1.282490
# batch 1515 d_loss : 0.414464
# batch 1515 g_loss : 1.126107
# batch 1516 d_loss : 0.440267
# batch 1516 g_loss : 1.187927
# batch 1517 d_loss : 0.389829
# batch 1517 g_loss : 1.416939
# batch 1518 d_loss : 0.372797
# batch 1518 g_loss : 1.342316
# batch 1519 d_loss : 0.418831
# batch 1519 g_loss : 1.072407
# batch 1520 d_loss : 0.428364
# batch 1520 g_loss : 1.422457
# batch 1521 d_loss : 0.383385
# batch 1521 g_loss : 1.232306
# batch 1522 d_loss : 0.405865
# batch 1522 g_loss : 1.324649
# batch 1523 d_loss : 0.326926
# batch 1523 g_loss : 1.658808
# batch 1524 d_loss : 0.418170
# batch 1524 g_loss : 0.877689
# batch 1525 d_loss : 0.400060
# batch 1525 g_loss : 1.441547
# batch 1526 d_loss : 0.347728
# batch 1526 g_loss : 1.252321
# batch 1527 d_loss : 0.380126
# batch 1527 g_loss : 1.374278
# batch 1528 d_loss : 0.379827
# batch 1528 g_loss : 1.381906
# batch 1529 d_loss : 0.342181
# batch 1529 g_loss : 1.815555
# batch 1530 d_loss : 0.474035
# batch 1530 g_loss : 1.074714
# batch 1531 d_loss : 0.342448
# batch 1531 g_loss : 1.617933
# batch 1532 d_loss : 0.359285
# batch 1532 g_loss : 1.358010
# batch 1533 d_loss : 0.371200
# batch 1533 g_loss : 1.782293
# batch 1534 d_loss : 0.600192
# batch 1534 g_loss : 0.643583
# batch 1535 d_loss : 0.590036
# batch 1535 g_loss : 1.389993
# batch 1536 d_loss : 0.541604
# batch 1536 g_loss : 1.386330
# batch 1537 d_loss : 0.408077
# batch 1537 g_loss : 1.638875
# batch 1538 d_loss : 0.445265
# batch 1538 g_loss : 1.112910
# batch 1539 d_loss : 0.357465
# batch 1539 g_loss : 1.642792
# batch 1540 d_loss : 0.356857
# batch 1540 g_loss : 1.220136
# batch 1541 d_loss : 0.339793
# batch 1541 g_loss : 2.008899
# batch 1542 d_loss : 0.404319
# batch 1542 g_loss : 1.252266
# batch 1543 d_loss : 0.313799
# batch 1543 g_loss : 1.716372
# batch 1544 d_loss : 0.428399
# batch 1544 g_loss : 1.021757
# batch 1545 d_loss : 0.361098
# batch 1545 g_loss : 1.686655
# batch 1546 d_loss : 0.514048
# batch 1546 g_loss : 0.639435
# batch 1547 d_loss : 0.522573
# batch 1547 g_loss : 2.337730
# batch 1548 d_loss : 0.463009
# batch 1548 g_loss : 0.874241
# batch 1549 d_loss : 0.413041
# batch 1549 g_loss : 1.926213
# batch 1550 d_loss : 0.548781
# batch 1550 g_loss : 0.873169
# batch 1551 d_loss : 0.392824
# batch 1551 g_loss : 3.205336
# batch 1552 d_loss : 0.498932
# batch 1552 g_loss : 0.797575
# batch 1553 d_loss : 0.436052
# batch 1553 g_loss : 2.740058
# batch 1554 d_loss : 0.382653
# batch 1554 g_loss : 1.435918
# batch 1555 d_loss : 0.320058
# batch 1555 g_loss : 1.645109
# batch 1556 d_loss : 0.307551
# batch 1556 g_loss : 1.358608
# batch 1557 d_loss : 0.371936
# batch 1557 g_loss : 1.513811
# batch 1558 d_loss : 0.394160
# batch 1558 g_loss : 0.891627
# batch 1559 d_loss : 0.416192
# batch 1559 g_loss : 1.865770
# batch 1560 d_loss : 0.503652
# batch 1560 g_loss : 0.751146
# batch 1561 d_loss : 0.632863
# batch 1561 g_loss : 2.516732
# batch 1562 d_loss : 0.480862
# batch 1562 g_loss : 1.031213
# batch 1563 d_loss : 0.351946
# batch 1563 g_loss : 1.532167
# batch 1564 d_loss : 0.344215
# batch 1564 g_loss : 1.321301
# batch 1565 d_loss : 0.418658
# batch 1565 g_loss : 1.748382
# batch 1566 d_loss : 0.409272
# batch 1566 g_loss : 0.941171
# batch 1567 d_loss : 0.409487
# batch 1567 g_loss : 2.455876
# batch 1568 d_loss : 0.389556
# batch 1568 g_loss : 1.184013
# batch 1569 d_loss : 0.378141
# batch 1569 g_loss : 2.290995
# batch 1570 d_loss : 0.377100
# batch 1570 g_loss : 1.373594
# batch 1571 d_loss : 0.306899
# batch 1571 g_loss : 1.702514
# batch 1572 d_loss : 0.462972
# batch 1572 g_loss : 1.010722
# batch 1573 d_loss : 0.383002
# batch 1573 g_loss : 2.077810
# batch 1574 d_loss : 0.363615
# batch 1574 g_loss : 1.395382
# batch 1575 d_loss : 0.323917
# batch 1575 g_loss : 1.795790
# batch 1576 d_loss : 0.413810
# batch 1576 g_loss : 1.142109
# batch 1577 d_loss : 0.435154
# batch 1577 g_loss : 1.513822
# batch 1578 d_loss : 0.349472
# batch 1578 g_loss : 1.333489
# batch 1579 d_loss : 0.336765
# batch 1579 g_loss : 2.009199
# batch 1580 d_loss : 0.362831
# batch 1580 g_loss : 0.926449
# batch 1581 d_loss : 0.367099
# batch 1581 g_loss : 2.413964
# batch 1582 d_loss : 0.308614
# batch 1582 g_loss : 1.772267
# batch 1583 d_loss : 0.325507
# batch 1583 g_loss : 1.334555
# batch 1584 d_loss : 0.249861
# batch 1584 g_loss : 2.542728
# batch 1585 d_loss : 0.448940
# batch 1585 g_loss : 1.307123
# batch 1586 d_loss : 0.436861
# batch 1586 g_loss : 1.395722
# batch 1587 d_loss : 0.373557
# batch 1587 g_loss : 1.574589
# batch 1588 d_loss : 0.375274
# batch 1588 g_loss : 1.186262
# batch 1589 d_loss : 0.376186
# batch 1589 g_loss : 1.827222
# batch 1590 d_loss : 0.453070
# batch 1590 g_loss : 1.222974
# batch 1591 d_loss : 0.380267
# batch 1591 g_loss : 1.901362
# batch 1592 d_loss : 0.327800
# batch 1592 g_loss : 2.020740
# batch 1593 d_loss : 0.318659
# batch 1593 g_loss : 1.271689
# batch 1594 d_loss : 0.265260
# batch 1594 g_loss : 2.221994
# batch 1595 d_loss : 0.300194
# batch 1595 g_loss : 1.711645
# batch 1596 d_loss : 0.324672
# batch 1596 g_loss : 1.873181
# batch 1597 d_loss : 0.407883
# batch 1597 g_loss : 1.391301
# batch 1598 d_loss : 0.564800
# batch 1598 g_loss : 1.290219
# batch 1599 d_loss : 0.620579
# batch 1599 g_loss : 1.098063
# batch 1600 d_loss : 0.651533
# batch 1600 g_loss : 1.429771
# batch 1601 d_loss : 0.611347
# batch 1601 g_loss : 1.222847
# batch 1602 d_loss : 0.557486
# batch 1602 g_loss : 1.345451
# batch 1603 d_loss : 0.455040
# batch 1603 g_loss : 1.385850
# batch 1604 d_loss : 0.503234
# batch 1604 g_loss : 1.624120
# batch 1605 d_loss : 0.435727
# batch 1605 g_loss : 1.076545
# batch 1606 d_loss : 0.352329
# batch 1606 g_loss : 2.064335
# batch 1607 d_loss : 0.431330
# batch 1607 g_loss : 1.229568
# batch 1608 d_loss : 0.415196
# batch 1608 g_loss : 1.317965
# batch 1609 d_loss : 0.368173
# batch 1609 g_loss : 1.783598
# batch 1610 d_loss : 0.389459
# batch 1610 g_loss : 1.342144
# batch 1611 d_loss : 0.323479
# batch 1611 g_loss : 1.338295
# batch 1612 d_loss : 0.300714
# batch 1612 g_loss : 1.741168
# batch 1613 d_loss : 0.368128
# batch 1613 g_loss : 1.475045
# batch 1614 d_loss : 0.366324
# batch 1614 g_loss : 1.574747
# batch 1615 d_loss : 0.306603
# batch 1615 g_loss : 1.527155
# batch 1616 d_loss : 0.383787
# batch 1616 g_loss : 1.632620
# batch 1617 d_loss : 0.330679
# batch 1617 g_loss : 1.641105
# batch 1618 d_loss : 0.273120
# batch 1618 g_loss : 1.696555
# batch 1619 d_loss : 0.313415
# batch 1619 g_loss : 1.749514
# batch 1620 d_loss : 0.276104
# batch 1620 g_loss : 2.408195
# batch 1621 d_loss : 0.296722
# batch 1621 g_loss : 1.914527
# batch 1622 d_loss : 0.367856
# batch 1622 g_loss : 1.594940
# batch 1623 d_loss : 0.454203
# batch 1623 g_loss : 1.764559
# batch 1624 d_loss : 0.358941
# batch 1624 g_loss : 1.769799
# batch 1625 d_loss : 0.332409
# batch 1625 g_loss : 1.865885
# batch 1626 d_loss : 0.251224
# batch 1626 g_loss : 2.414574
# batch 1627 d_loss : 0.432487
# batch 1627 g_loss : 1.030392
# batch 1628 d_loss : 0.505014
# batch 1628 g_loss : 2.193525
# batch 1629 d_loss : 0.552896
# batch 1629 g_loss : 0.749629
# batch 1630 d_loss : 0.473955
# batch 1630 g_loss : 2.530683
# batch 1631 d_loss : 0.433636
# batch 1631 g_loss : 1.239737
# batch 1632 d_loss : 0.286725
# batch 1632 g_loss : 1.790278
# batch 1633 d_loss : 0.378686
# batch 1633 g_loss : 1.181203
# batch 1634 d_loss : 0.447950
# batch 1634 g_loss : 2.168179
# batch 1635 d_loss : 0.351449
# batch 1635 g_loss : 1.049619
# batch 1636 d_loss : 0.328427
# batch 1636 g_loss : 2.353460
# batch 1637 d_loss : 0.506751
# batch 1637 g_loss : 0.959947
# batch 1638 d_loss : 0.509419
# batch 1638 g_loss : 1.648051
# batch 1639 d_loss : 0.445095
# batch 1639 g_loss : 1.544820
# batch 1640 d_loss : 0.270231
# batch 1640 g_loss : 2.078279
# batch 1641 d_loss : 0.250494
# batch 1641 g_loss : 1.779403
# batch 1642 d_loss : 0.276206
# batch 1642 g_loss : 1.948270
# batch 1643 d_loss : 0.292410
# batch 1643 g_loss : 1.510383
# batch 1644 d_loss : 0.308361
# batch 1644 g_loss : 1.778504
# batch 1645 d_loss : 0.328926
# batch 1645 g_loss : 1.923113
# batch 1646 d_loss : 0.259946
# batch 1646 g_loss : 1.495810
# batch 1647 d_loss : 0.356989
# batch 1647 g_loss : 1.585872
# batch 1648 d_loss : 0.280149
# batch 1648 g_loss : 1.361844
# batch 1649 d_loss : 0.308878
# batch 1649 g_loss : 2.500439
# batch 1650 d_loss : 0.434134
# batch 1650 g_loss : 1.191573
# batch 1651 d_loss : 0.302311
# batch 1651 g_loss : 1.898241
# batch 1652 d_loss : 0.386931
# batch 1652 g_loss : 1.402878
# batch 1653 d_loss : 0.314246
# batch 1653 g_loss : 1.748185
# batch 1654 d_loss : 0.350439
# batch 1654 g_loss : 1.964502
# batch 1655 d_loss : 0.352371
# batch 1655 g_loss : 1.084951
# batch 1656 d_loss : 0.385932
# batch 1656 g_loss : 2.081064
# batch 1657 d_loss : 0.250469
# batch 1657 g_loss : 1.958902
# batch 1658 d_loss : 0.295642
# batch 1658 g_loss : 1.728915
# batch 1659 d_loss : 0.353602
# batch 1659 g_loss : 1.578702
# batch 1660 d_loss : 0.294409
# batch 1660 g_loss : 1.468556
# batch 1661 d_loss : 0.287130
# batch 1661 g_loss : 1.764202
# batch 1662 d_loss : 0.294151
# batch 1662 g_loss : 1.162950
# batch 1663 d_loss : 0.341563
# batch 1663 g_loss : 1.703093
# batch 1664 d_loss : 0.293549
# batch 1664 g_loss : 1.728027
# batch 1665 d_loss : 0.297887
# batch 1665 g_loss : 1.504023
# batch 1666 d_loss : 0.328541
# batch 1666 g_loss : 1.978812
# batch 1667 d_loss : 0.233691
# batch 1667 g_loss : 1.732857
# batch 1668 d_loss : 0.310222
# batch 1668 g_loss : 1.613975
# batch 1669 d_loss : 0.231284
# batch 1669 g_loss : 1.772496
# batch 1670 d_loss : 0.273979
# batch 1670 g_loss : 1.480558
# batch 1671 d_loss : 0.314004
# batch 1671 g_loss : 1.912814
# batch 1672 d_loss : 0.281113
# batch 1672 g_loss : 1.598307
# batch 1673 d_loss : 0.259955
# batch 1673 g_loss : 2.182966
# batch 1674 d_loss : 0.249142
# batch 1674 g_loss : 1.944813
# batch 1675 d_loss : 0.246472
# batch 1675 g_loss : 1.720087
# batch 1676 d_loss : 0.324897
# batch 1676 g_loss : 1.783310
# batch 1677 d_loss : 0.284591
# batch 1677 g_loss : 2.374944
# batch 1678 d_loss : 0.249817
# batch 1678 g_loss : 1.445987
# batch 1679 d_loss : 0.320190
# batch 1679 g_loss : 1.867026
# batch 1680 d_loss : 0.263830
# batch 1680 g_loss : 1.941696
# batch 1681 d_loss : 0.224195
# batch 1681 g_loss : 1.688679
# batch 1682 d_loss : 0.249953
# batch 1682 g_loss : 2.185152
# batch 1683 d_loss : 0.305925
# batch 1683 g_loss : 1.679708
# batch 1684 d_loss : 0.335633
# batch 1684 g_loss : 1.927253
# batch 1685 d_loss : 0.286419
# batch 1685 g_loss : 1.663959
# batch 1686 d_loss : 0.246341
# batch 1686 g_loss : 1.738939
# batch 1687 d_loss : 0.371264
# batch 1687 g_loss : 1.785191
# batch 1688 d_loss : 0.307849
# batch 1688 g_loss : 1.223047
# batch 1689 d_loss : 0.353045
# batch 1689 g_loss : 1.912042
# batch 1690 d_loss : 0.349718
# batch 1690 g_loss : 1.941754
# batch 1691 d_loss : 0.311640
# batch 1691 g_loss : 1.692480
# batch 1692 d_loss : 0.338410
# batch 1692 g_loss : 1.483595
# batch 1693 d_loss : 0.263335
# batch 1693 g_loss : 1.483708
# batch 1694 d_loss : 0.305640
# batch 1694 g_loss : 1.897009
# batch 1695 d_loss : 0.299499
# batch 1695 g_loss : 1.506757
# batch 1696 d_loss : 0.272392
# batch 1696 g_loss : 2.521780
# batch 1697 d_loss : 0.432295
# batch 1697 g_loss : 0.723632
# batch 1698 d_loss : 0.443234
# batch 1698 g_loss : 2.619807
# batch 1699 d_loss : 0.547665
# batch 1699 g_loss : 0.600263
# batch 1700 d_loss : 0.576205
# batch 1700 g_loss : 3.784259
# batch 1701 d_loss : 0.635016
# batch 1701 g_loss : 1.013230
# batch 1702 d_loss : 0.452925
# batch 1702 g_loss : 2.508664
# batch 1703 d_loss : 0.262468
# batch 1703 g_loss : 2.005961
# batch 1704 d_loss : 0.409529
# batch 1704 g_loss : 1.073724
# batch 1705 d_loss : 0.375286
# batch 1705 g_loss : 2.691763
# batch 1706 d_loss : 0.320063
# batch 1706 g_loss : 1.657935
